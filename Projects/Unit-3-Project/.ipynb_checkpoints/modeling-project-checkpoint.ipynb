# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 3: Statistical Modeling and Model Validation
#
# ---

# %% [markdown]
# ## Objective
# The goal of this assessment is to guide you through the modeling workflow to produce the best possible model. In this lesson, you will apply the best practices you've learned to date to slice your data and validate your model.
#
# You'll demonstrate the following skills:
#
# **Linear Regression**
# * Handling categorical features in a scikit-learn model.
# * Carrying out a train/test split.
# * Training a model.
# * Evaluating that model on the testing data.
#
# **K-Nearest Neighbors:**
# * Preparing your data for modeling.
# * Scaling your data.
# * Tuning a hyperparameter using k-fold cross-validation.
# * Selecting a model based on a tuning parameter.
# * Using a model to make predictions on new data.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats

# %% [markdown]
# # Part 1: Regression on MPG Data

# %% [markdown]
# ## Read the Data
# The [`mpg` data set](https://archive.ics.uci.edu/ml/datasets/auto+mpg) represents the fuel economy (in miles per gallon) for 38 popular models of car, measured between 1999 and 2008.
#
# |Factor      |Type                              |Description                                               |
# |------------|----------------------------------|----------------------------------------------------------|
# |manufacturer|multi-valued discrete             |Vehicle manufacturer                                      |
# |model       |multi-valued discrete             |Model of the vehicle                                      |
# |displ       |continuous                        |Size of engine [litres]                                   |
# |year        |multi-valued discrete             |Year of vehicle manufacture                               |
# |cyl         |multi-valued discrete             |Number of ignition cylinders                              |
# |trans       |multi-valued discrete             |Transmission type (manual or automatic)                   |
# |drv         |multi-valued discrete             |Driven wheels (f=front, 4=4-wheel, r=rear wheel drive)    |
# |city        |continuous                        |Miles per gallon, city driving conditions (fuel economy)  |
# |fl          |multi-valued discrete             |Vehicle type                                              |
# |class       |multi-valued discrete             |Vehicle class (suv, compact, etc)                         |

# %%
# Read the mpg data in the data folder into this repository.
mpg = pd.read_csv('data/mpg.csv')

# %% [markdown]
# ## Explore the Data
# Use this space to familiarize yourself with the data set.
#
# Convince yourself that there are no issues with the data. If you find any, clean them now.

# %%
mpg.head(15)
# Out:
#    manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0          audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1          audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2          audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3          audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4          audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5          audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6          audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7          audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# 8          audi  a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# 9          audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 10         audi  a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
# 11         audi  a4 quattro    2.8  1999    6    auto(l5)   4   15   25  p
# 12         audi  a4 quattro    2.8  1999    6  manual(m5)   4   17   25  p
# 13         audi  a4 quattro    3.1  2008    6    auto(s6)   4   17   25  p
# 14         audi  a4 quattro    3.1  2008    6  manual(m6)   4   15   25  p
#
#       class
# 0   compact
# 1   compact
# 2   compact
# 3   compact
# 4   compact
# 5   compact
# 6   compact
# 7   compact
# 8   compact
# 9   compact
# 10  compact
# 11  compact
# 12  compact
# 13  compact
# 14  compact

# %%
mpg.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# class           0
# dtype: int64

# %% [markdown]
# ## Dummify the `drv` Variable

# %%
pd.get_dummies(mpg["drv"])
# Out:
#      4  f  r
# 0    0  1  0
# 1    0  1  0
# 2    0  1  0
# 3    0  1  0
# 4    0  1  0
# 5    0  1  0
# 6    0  1  0
# 7    1  0  0
# 8    1  0  0
# 9    1  0  0
# 10   1  0  0
# 11   1  0  0
# 12   1  0  0
# 13   1  0  0
# 14   1  0  0
# 15   1  0  0
# 16   1  0  0
# 17   1  0  0
# 18   0  0  1
# 19   0  0  1
# 20   0  0  1
# 21   0  0  1
# 22   0  0  1
# 23   0  0  1
# 24   0  0  1
# 25   0  0  1
# 26   0  0  1
# 27   0  0  1
# 28   1  0  0
# 29   1  0  0
# ..  .. .. ..
# 204  1  0  0
# 205  1  0  0
# 206  1  0  0
# 207  0  1  0
# 208  0  1  0
# 209  0  1  0
# 210  0  1  0
# 211  0  1  0
# 212  0  1  0
# 213  0  1  0
# 214  0  1  0
# 215  0  1  0
# 216  0  1  0
# 217  0  1  0
# 218  0  1  0
# 219  0  1  0
# 220  0  1  0
# 221  0  1  0
# 222  0  1  0
# 223  0  1  0
# 224  0  1  0
# 225  0  1  0
# 226  0  1  0
# 227  0  1  0
# 228  0  1  0
# 229  0  1  0
# 230  0  1  0
# 231  0  1  0
# 232  0  1  0
# 233  0  1  0
#
# [234 rows x 3 columns]

# %%
mpgDummies = pd.get_dummies(mpg, columns=['drv'])

mpgDummies.head()
# Out:
#   manufacturer model  displ  year  cyl       trans  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   16   26  p  compact
#
#    drv_4  drv_f  drv_r
# 0      0      1      0
# 1      0      1      0
# 2      0      1      0
# 3      0      1      0
# 4      0      1      0

# %% [markdown]
# ## Split Your Data Into Factors (`X`) and Target (`y`)
# You only need to keep the `displ` and `drv` variable(s) here, as those are the only columns you'll be fitting your model on in the next section.

# %%
# Create X and y
X = mpgDummies[['displ' , 'drv_4' , 'drv_f' , 'drv_r']]
y = mpgDummies.hwy

# %% [markdown]
# ## Instantiate a Linear Regression Model Object Predicting Highway MPG
# Instantiate a `LinearRegression` object here.

# %%
#Instantiate
#from sklearn.linear_model import LinearRegression
#lr = LinearRegression()
#lr.fit(X, y)

#Split the data in 75% training and 25% testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
#Scale the data (Feature Scaling) to bring all the features to the same level of magnitude. All data will be in a specific range. 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
#Logistic Regression Model
def LinReg_Model(X_train, y_train):
    from sklearn.linear_model import LogisticRegression
    log = LogisticRegression(random_state=0)
    log.fit(X_train, y_train)
    
    print('[0]Logistic Regression Training Accuracy:', log.score(X_train, y_train))
    
    return log

# %% [markdown]
# ## Evaluate Your Model
#
# - Run five-fold cross-validation on your data.
#   - Report the mean of the mean squared error across five folds.
#   - Report the mean R-squared value across five folds.

# %%
#Logistic Regression Model Training Accuracy
model = LinReg_Model(X_train, y_train)
# Out:
# [0]Logistic Regression Training Accuracy: 0.28
# C:\Users\601113\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\601113\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
from sklearn import metrics

y_pred = log.predict(X_test)

print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MSE: 24.847457627118644
# RMSE: 4.984722422273746

# %% [markdown]
# # Part 2: Classification Using KNN

# %% [markdown]
# ## Read in the `diamonds` Data
# This is data regarding 50,000 round-cut diamonds.
#
# |Factor            |Description                                                                                 |
# |------------------|--------------------------------------------------------------------------------------------|
# |price             |price in US dollars (326-18,823)                                                            |
# |carat             |weight of the diamond (0.2--5.01)                                                           |
# |cut               |quality of the cut (Fair, Good, Very Good, Premium, Ideal)                                  |
# |color             |diamond colour, from J (worst) to D (best)                                                  |
# |clarity           |how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))            |
# |x                 |length in mm (0--10.74)                                                                     |
# |y                 |width in mm (0--58.9)                                                                       |
# |z                 |depth in mm (0--31.8)                                                                       |
# |depth             |total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)                          |
# |table             |width of top of diamond relative to widest point (43--95)                                   |

# %%
dia = pd.read_csv('data/diamonds.csv')

# %% [markdown]
# ## Explore the Data

# %%
dia.head(30)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12   0.22    Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 13   0.31      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 14   0.20    Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15   0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 16   0.30      Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 17   0.30       Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70
# 18   0.30       Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71
# 19   0.30  Very Good     J     SI1   62.7   59.0    351  4.21  4.27  2.66
# 20   0.30       Good     I     SI2   63.3   56.0    351  4.26  4.30  2.71
# 21   0.23  Very Good     E     VS2   63.8   55.0    352  3.85  3.92  2.48
# 22   0.23  Very Good     H     VS1   61.0   57.0    353  3.94  3.96  2.41
# 23   0.31  Very Good     J     SI1   59.4   62.0    353  4.39  4.43  2.62
# 24   0.31  Very Good     J     SI1   58.1   62.0    353  4.44  4.47  2.59
# 25   0.23  Very Good     G    VVS2   60.4   58.0    354  3.97  4.01  2.41
# 26   0.24    Premium     I     VS1   62.5   57.0    355  3.97  3.94  2.47
# 27   0.30  Very Good     J     VS2   62.2   57.0    357  4.28  4.30  2.67
# 28   0.23  Very Good     D     VS2   60.5   61.0    357  3.96  3.97  2.40
# 29   0.23  Very Good     F     VS1   60.9   57.0    357  3.96  3.99  2.42

# %%
dia.shape
# Out:
# (53940, 10)

# %%
dia.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# ## Filter Your Data
# Filter your data to only contain diamonds with `'Ideal'` and `'Good'` cuts.

# %%
dia = dia.drop(dia[(dia.cut == "Premium")].index)
dia = dia.drop(dia[(dia.cut == "Very Good")].index)
dia = dia.drop(dia[(dia.cut == "Fair")].index)
dia.head(30)
# Out:
#     carat    cut color clarity  depth  table  price     x     y     z
# 0    0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2    0.23   Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4    0.31   Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 10   0.30   Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23  Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 13   0.31  Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 16   0.30  Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 17   0.30   Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70
# 18   0.30   Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71
# 20   0.30   Good     I     SI2   63.3   56.0    351  4.26  4.30  2.71
# 35   0.23   Good     F     VS1   58.2   59.0    402  4.06  4.08  2.37
# 36   0.23   Good     E     VS1   64.1   59.0    402  3.83  3.85  2.46
# 37   0.31   Good     H     SI1   64.0   54.0    402  4.29  4.31  2.75
# 39   0.33  Ideal     I     SI2   61.8   55.0    403  4.49  4.51  2.78
# 40   0.33  Ideal     I     SI2   61.2   56.0    403  4.49  4.50  2.75
# 41   0.33  Ideal     J     SI1   61.1   56.0    403  4.49  4.55  2.76
# 42   0.26   Good     D     VS2   65.2   56.0    403  3.99  4.02  2.61
# 43   0.26   Good     D     VS1   58.4   63.0    403  4.19  4.24  2.46
# 44   0.32   Good     H     SI2   63.1   56.0    403  4.34  4.37  2.75
# 47   0.32   Good     H     SI2   63.8   56.0    403  4.36  4.38  2.79
# 51   0.23  Ideal     G     VS1   61.9   54.0    404  3.93  3.95  2.44
# 52   0.32  Ideal     I     SI1   60.9   55.0    404  4.45  4.48  2.72
# 55   0.30  Ideal     I     SI2   61.0   59.0    405  4.30  4.33  2.63
# 59   0.30   Good     I     SI1   63.2   55.0    405  4.25  4.29  2.70
# 60   0.35  Ideal     I     VS1   60.9   57.0    552  4.54  4.59  2.78
# 62   0.30  Ideal     D     SI1   62.5   57.0    552  4.29  4.32  2.69
# 63   0.30  Ideal     D     SI1   62.1   56.0    552  4.30  4.33  2.68
# 65   0.28  Ideal     G    VVS2   61.4   56.0    553  4.19  4.22  2.58
# 66   0.32  Ideal     I    VVS1   62.0   55.3    553  4.39  4.42  2.73
# 74   0.30   Good     H     SI1   63.7   57.0    554  4.28  4.26  2.72

# %% [markdown]
# ## Downsample the Majority Class

# %%
# Separate majority and minority classes
dia['cut'].value_counts()
dia_majority = dia[dia.cut=="Ideal"]
dia_minority = dia[dia.cut=="Good"]

#Downsample majority class
from sklearn.utils import resample
dia_majority_downsampled = resample(dia_majority, replace=False, n_samples=49, random_state=123)

# %% [markdown]
# ## Prepare Your `X`, `y` Matrices
# Construct an `X` matrix using **all numeric columns** from the `diamonds` data.
#
# You will be predicting `cut`. Construct a `y` vector in a numeric format that can be used by scikit-learn.

# %%
#Encode the categorical data values. Change the values in the 'cut' column from 1 and 0
from sklearn.preprocessing import LabelEncoder
le_Y = LabelEncoder()
dia.iloc[:,1] = le_Y.fit_transform(dia.iloc[:,1].values)

# %% [markdown]
# ## Scale Your `X` Matrix Using a StandardScaler

# %%
#Scale the data (Feature Scaling) to bring all the features to the same level of magnitude. All data will be in a specific range. 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# ## Why Did We Just Do That?
# In the cell below, provide a 2–3 sentence explanation of why scaling our $X$ matrix was necessary here. What could have gone wrong if we didn't?

# %% [markdown]
# Scaling for KNN is important because KNN uses the distance between two points. If two features are on different scales, the distances between them on each coordinate might be given falsely disproportionate weights. If we didn't scale, it's possible that KNN would make all of its decisions based on the feature with the widest scale.

# %% [markdown]
# ## Split Into Testing and Training Groups
#
# Now that we've downsampled/balanced our classes, as well as removed unused factors, we're ready to split into testing and training groups. We're doing this avoid _leaking information into our testing set_.
#
# - First, we'll perform cross-validation on our _training_ set, finding an optimal value for $k$.
# - After this, we'll take that value of $k$ and use it to fit our model to the _training_ set, creating our tuned model.
# - Finally, we will take this same model and use it to _predict_ and _score_ against our _testing_ set.
# - Note that our model at this point will have never seen nor trained against the _testing_ set.
#
# In the future, we can (and should!) automate this process using a [pipeline](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html) — a tool used to abstract our modeling process, allowing data to be processed without manual intervention.

# %%
# Create X and y
X = dia.iloc[:,4:10]
y = dia.cut

# %%
#Split the data in 75% training and 25% testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ## K-Nearest Neighbors
# You're going to fit a KNN model here, but you first need to tune your model to find the best value of $k$. Loop through values of $k$ you think are appropriate (Hint: Look for "elbows" in your result curves) and select the value that produces the best model with respect to **five-fold cross-validation**.
#
# **Important**: Do not use _any_ code copied and pasted directly from the lecture! Typing things out yourself is 100% essential to the learning process. It's OK to use the exact same strategies as we did in class, but be sure to enter them manually.

# %%
from sklearn.neighbors import KNeighborsClassifier
error_rate = []

for i in range(1,50):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %% [markdown]
# ## Produce the Plot of Tuning Parameter ($k$) vs. Accuracy
# What is the "best" value of k?

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,50),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# ## Produce the Best KNN Model
# Now that you know the optimal value of $k$, fit a KNN on the training set (this training set should still filtered to `'Ideal'` and `'Good'` cuts).

# %%
from sklearn import grid_search

k = np.arange(100) + 1
knn = KNeighborsClassifier()

params = {'n_neighbors': k}

gs = grid_search.GridSearchCV(    
    estimator= knn,
    param_grid= params,
    cv=5)

gs.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-206-58e9689aae47> in <module>
# ----> 1 from sklearn import grid_search
#       2
#       3 k = np.arange(100) + 1
#       4 knn = KNeighborsClassifier()
#       5
#
# ImportError: cannot import name 'grid_search' from 'sklearn' (C:\Users\601113\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\__init__.py)

# %% [markdown]
# ## Does This Model Outperform the Baseline?

# %% [markdown]
# ## Prediction
# Suppose I have a diamond with the following specifications:

# %%
new_diamond = pd.DataFrame({
    'carat': 0.24,
    'depth': 60.,
    'table': 64.,
    'price': 400.,
    'x': 3.,
    'y': 3.,
    'z': 3.
}, index=[0])

# %% [markdown]
# What do you predict to be the cut of this diamond?
#
# **Big hint:** Don't forget to scale this new data point appropriately!

# %% [markdown]
# # Part 3: Now _YOU_ Model!
# Put your skills to the test.

# %% [markdown]
# Using the _full_ `diamonds` data set, produce a **logistic regression** model that achieves the best five-fold cross-validation. Note that, for this problem, you're performing multi-class classification. The response variable has _five_ categories.

# %%
dia = pd.read_csv('data/diamonds.csv')

# %%
# Create X and y
X = dia.iloc[:,4:10]
y = dia.cut

# %%
#Split the data in 75% training and 25% testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
#Scale the data (Feature Scaling) to bring all the features to the same level of magnitude. All data will be in a specific range. 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
#Create a function for the model
def model(X_train, Y_train):
    
    #Logistic Regression
    from sklearn.linear_model import LogisticRegression
    log = LogisticRegression(random_state=0)
    log.fit(X_train, Y_train)
    
    #Print the model accuracy on the training data
    print('[0]Logistic Regression Training Accuracy:', log.score(X_train, Y_train))
    
    return log

# %%
#Training accuracy for the model
model = model(X_train, Y_train)
# Out:
# C:\Users\601113\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\601113\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# [0]Logistic Regression Training Accuracy: 0.6477320479545173

# %%
#Test model accuracy on test data using classification report and accuracy score.
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

print(classification_report(Y_test, model.predict(X_test)))
print(accuracy_score(Y_test, model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#         Fair       0.97      0.42      0.58       409
#         Good       0.43      0.01      0.01      1219
#        Ideal       0.70      0.92      0.79      5325
#      Premium       0.66      0.68      0.67      3489
#    Very Good       0.46      0.40      0.43      3043
#
#     accuracy                           0.64     13485
#    macro avg       0.64      0.49      0.50     13485
# weighted avg       0.62      0.64      0.60     13485
#
# 0.6432332220986281
